# %%
from astropy.io import fits
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from glob import glob
import numpy as np
import sys

from spyffier import Pipeline

# %%
# indicate the path to the esorex executable
esorex_path = '/path-to-esorex/bin/esorex'
# indicate the path to the data
raw_path = '/path-to-data/raw/'
# indicate the path to the folder where the output files are create
reduction_path = '/path-to-output/spyffier/'

# %%
# initiate the pipeline
# at the moment, the pipeline only supports one observing night and one instrument configuration (grating and plate scale). 
# if you need to reduce data from different nights or different instrument configurations, you need to use several pipeline objects.
pipeline = Pipeline(esorex_path = esorex_path, reduction_path = reduction_path, raw_path = raw_path, wavel_setting = 'K_long')

# %%
# extract header information
pipeline.extract_header()

# %%
# identify unique (DITxNDIT) of your observations
unique_dit_ndit = pipeline._identify_science_dit_ndit()

# %%
# identify unique DITs
unique_dits = list(dict.fromkeys(list(map(lambda x: x[0],unique_dit_ndit))))

# %%
# create master DARKS for each DIT
for dit in unique_dits:
    pipeline.calib_dark(dit=dit)

# %%
# derive the detector linearity
pipeline.calib_detlin()

# %%
# calculate the distortion
pipeline.calib_distortion(spiffier_gw = 'K_long', spiffier_psw = '250mas')

# %%
# create master FLATs
pipeline.calib_flat(spiffier_gw = 'K_long', spiffier_psw = '250mas',dit=60)

# %%
# derive the wavelength map
pipeline.calib_wavecal(spiffier_gw = 'K_long', spiffier_psw = '250mas')

# %%
# identify object - sky pairs, grouped in time
files_groups = {}
for dit,ndit in unique_dit_ndit:
    files_groups[f'{dit}_{ndit}'] = pipeline._identify_obj_sky_groups_by_time(
        obj_tag = 'OBJECT',sky_tag = 'SKY', dit = dit, ndit = int(ndit),
        spiffier_gw = 'K_long', spiffier_psw = '250mas')

# %%
for dit,ndit in unique_dit_ndit:
    for files_group_i in files_groups[f'{dit}_{ndit}'].keys():
        obj_files = files_groups[f'{dit}_{ndit}'][files_group_i]['OBJECT']
        sky_files = files_groups[f'{dit}_{ndit}'][files_group_i]['SKY']
        pipeline.science_ifu_jitter(
            dit = 60, ndit = 1,spiffier_gw = 'K_long', spiffier_psw = '250mas', 
            obj_date_obs = obj_files, sky_date_obs = sky_files,
            new_config={'cube.combine':'FALSE','sky_tweak':1,'aj-method':2,'tbsub':'TRUE'}, 
            output_name = f'product_g_{files_group_i}', use_corr_wavemap = None)

# %%
# explore the calibrated data
pipeline.file_dict['DAR_CORRECTED_CUBE']

# %%
# plot raw data
pipeline._plot_image(file_type='OBJ', 
        fits_folder=raw_path, 
        save = False,
        vmin_pc = 1,
        vmax_pc = 99)

# %%
# plot calibrated data, before being constructed into an image datacube
pipeline._plot_image(file_type='OBJECT_WAVE_B', 
        fits_folder=raw_path, 
        save = False,
        vmin_pc = 1,
        vmax_pc = 99.5)
